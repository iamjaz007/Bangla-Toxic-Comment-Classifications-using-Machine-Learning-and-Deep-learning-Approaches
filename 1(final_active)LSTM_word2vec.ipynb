# %%
import pandas as pd
import numpy as np
import string
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from collections import Counter
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import GridSearchCV
import io 

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset1 = pd.read_excel("/content/drive/MyDrive/datasett/finaldataset-2020-.xlsx")

# %%
dataset1
# Out:
#                                             comment_text  toxic  threat  \
# 0      এই গুলার জায়গামতো চুঁচড়া লাগিয়ে দেয়া দরকার! যত...      1       0
# 1      আসিফ খানকির পোলা, তোর মারে কুত্তা দিয়ে চুদে তো...      1       0
# 2      শুয়োরের জ্ঞান সীমিত তাই সারাদিন গাঁজাখোরদের মত...      1       0
# 3       এই মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি দেয়া হোক।      1       0
# 4                        নাস্তিকতা মানে ই মানুষিক রোগী ।      1       0
# ...                                                  ...    ...     ...
# 20198  চাকমা মারমা একই না?  চীন তাদের লাথি মেরেছে।  আ...      1       0
# 20199                          চাকমা মানি চাইনিজ মাফিয়া      1       0
# 20200  কাক কালো। আফ্রিকান কালো।  তুমিও কালো।  পাউডার ...      1       0
# 20201     খানকি সুন্দর হতে পারে কিন্তু   তুই নিগা থাকবি       1       0
# 20202                                শালা গরিব এর বাচ্চা      1       0
#
#        obscene  insult  racism  Labelss
# 0            0       1       0   insult
# 1            1       0       0  obscene
# 2            0       1       0   insult
# 3            0       1       0   insult
# 4            0       0       1   racism
# ...        ...     ...     ...      ...
# 20198        0       0       1   racism
# 20199        0       0       1   racism
# 20200        0       0       1   racism
# 20201        0       0       1   racism
# 20202        0       0       1   racism
#
# [20203 rows x 7 columns]

# %%
dataset1=dataset1.drop(['threat','obscene','insult','racism','toxic'],axis=1)

# %%
print(dataset1.dtypes)
# Out:
# comment_text    object
# Labelss         object
# dtype: object

# %%
dataset1.isnull().sum()
# Out:
# comment_text    0
# Labelss         0
# dtype: int64

# %%
dataset1
# Out:
#                                             comment_text  Labelss
# 0      এই গুলার জায়গামতো চুঁচড়া লাগিয়ে দেয়া দরকার! যত...   insult
# 1      আসিফ খানকির পোলা, তোর মারে কুত্তা দিয়ে চুদে তো...  obscene
# 2      শুয়োরের জ্ঞান সীমিত তাই সারাদিন গাঁজাখোরদের মত...   insult
# 3       এই মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি দেয়া হোক।   insult
# 4                        নাস্তিকতা মানে ই মানুষিক রোগী ।   racism
# ...                                                  ...      ...
# 20198  চাকমা মারমা একই না?  চীন তাদের লাথি মেরেছে।  আ...   racism
# 20199                          চাকমা মানি চাইনিজ মাফিয়া   racism
# 20200  কাক কালো। আফ্রিকান কালো।  তুমিও কালো।  পাউডার ...   racism
# 20201     খানকি সুন্দর হতে পারে কিন্তু   তুই নিগা থাকবি    racism
# 20202                                শালা গরিব এর বাচ্চা   racism
#
# [20203 rows x 2 columns]

# %%
#remove punctuations
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
        text=text.replace('।','')
        text=text.replace('৷','')
        text=text.replace('\n','')
    return text
# Apply to the DF series

#data['comment_text'] = data['comment_text'].str.replace('“”‘’','')
#data['comment_text'] = data['comment_text'].str.replace('’‘“”,'')

 #dataset2['comment_text'] = dataset2['comment_text'].str.replace('।','')

dataset1['comment_text'] = dataset1['comment_text'].apply(remove_punctuations)

# %%
dataset1['comment_text'].head(10000)
# Out:
# 0       এই গুলার জায়গামতো চুঁচড়া লাগিয়ে দেয়া দরকার যত্...
# 1       আসিফ খানকির পোলা তোর মারে কুত্তা দিয়ে চুদে তোর...
# 2       শুয়োরের জ্ঞান সীমিত তাই সারাদিন গাঁজাখোরদের মত...
# 3         এই মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি দেয়া হোক
# 4                          নাস্তিকতা মানে ই মানুষিক রোগী
#                               ...
# 9995    ভাত খাইতে বসছিলাম তোর এই নলাসুদা ছবি দেইখা খান...
# 9996    আজকের এই ছবিতেও যদি তুই গালি খাও অবশ্য খাইতেছ ...
# 9997                 এত কিছুর ভীড়ে এটা ভুলে যাওয়া উচিত না
# 9998                  ২০১৫ সালের নিউজ দিয়ে গুজব ছড়াবেন না
# 9999                    খানকির পোলা খায় শুটকি সুদে পেত্নি
# Name: comment_text, Length: 10000, dtype: object

# %%
#this worked hopefully to remove emojis
import re


def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               u"\u09E6-\u09EF"#banglanumerical code
                               u"\u0030-\u0039"#englishnumercal code
                               u"\u0041-\u005A"#uppercaseenglish alphabet
                               u"\u0061-\u007A"#lowercaseenglish alphabet
                               u"\u2019"
                               u"\u2018"
                               u"\u201C"
                               u"\u201D"
                               u"\u201E"
                               u"\u201F"

                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

dataset1['new']=dataset1['comment_text'].apply(remove_emoji)

# %%
dataset1
# Out:
#                                             comment_text  Labelss  \
# 0      এই গুলার জায়গামতো চুঁচড়া লাগিয়ে দেয়া দরকার যত্...   insult
# 1      আসিফ খানকির পোলা তোর মারে কুত্তা দিয়ে চুদে তোর...  obscene
# 2      শুয়োরের জ্ঞান সীমিত তাই সারাদিন গাঁজাখোরদের মত...   insult
# 3        এই মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি দেয়া হোক   insult
# 4                         নাস্তিকতা মানে ই মানুষিক রোগী    racism
# ...                                                  ...      ...
# 20198  চাকমা মারমা একই না  চীন তাদের লাথি মেরেছে  আর ...   racism
# 20199                          চাকমা মানি চাইনিজ মাফিয়া   racism
# 20200  কাক কালো আফ্রিকান কালো  তুমিও কালো  পাউডার দিয...   racism
# 20201     খানকি সুন্দর হতে পারে কিন্তু   তুই নিগা থাকবি    racism
# 20202                                শালা গরিব এর বাচ্চা   racism
#
#                                                      new
# 0      এই গুলার জায়গামতো চুঁচড়া লাগিয়ে দেয়া দরকার যত্...
# 1      আসিফ খানকির পোলা তোর মারে কুত্তা দিয়ে চুদে তোর...
# 2      শুয়োরের জ্ঞান সীমিত তাই সারাদিন গাঁজাখোরদের মত...
# 3        এই মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি দেয়া হোক
# 4                         নাস্তিকতা মানে ই মানুষিক রোগী
# ...                                                  ...
# 20198  চাকমা মারমা একই না  চীন তাদের লাথি মেরেছে  আর ...
# 20199                          চাকমা মানি চাইনিজ মাফিয়া
# 20200  কাক কালো আফ্রিকান কালো  তুমিও কালো  পাউডার দিয...
# 20201     খানকি সুন্দর হতে পারে কিন্তু   তুই নিগা থাকবি
# 20202                                শালা গরিব এর বাচ্চা
#
# [20203 rows x 3 columns]

# %%
columns_titles = ["new","comment_text","Labelss"]
multitoxicdata=dataset1.reindex(columns=columns_titles)

# %%
multitoxicdata
# Out:
#                                                      new  \
# 0      এই গুলার জায়গামতো চুঁচড়া লাগিয়ে দেয়া দরকার যত্...
# 1      আসিফ খানকির পোলা তোর মারে কুত্তা দিয়ে চুদে তোর...
# 2      শুয়োরের জ্ঞান সীমিত তাই সারাদিন গাঁজাখোরদের মত...
# 3        এই মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি দেয়া হোক
# 4                         নাস্তিকতা মানে ই মানুষিক রোগী
# ...                                                  ...
# 20198  চাকমা মারমা একই না  চীন তাদের লাথি মেরেছে  আর ...
# 20199                          চাকমা মানি চাইনিজ মাফিয়া
# 20200  কাক কালো আফ্রিকান কালো  তুমিও কালো  পাউডার দিয...
# 20201     খানকি সুন্দর হতে পারে কিন্তু   তুই নিগা থাকবি
# 20202                                শালা গরিব এর বাচ্চা
#
#                                             comment_text  Labelss
# 0      এই গুলার জায়গামতো চুঁচড়া লাগিয়ে দেয়া দরকার যত্...   insult
# 1      আসিফ খানকির পোলা তোর মারে কুত্তা দিয়ে চুদে তোর...  obscene
# 2      শুয়োরের জ্ঞান সীমিত তাই সারাদিন গাঁজাখোরদের মত...   insult
# 3        এই মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি দেয়া হোক   insult
# 4                         নাস্তিকতা মানে ই মানুষিক রোগী    racism
# ...                                                  ...      ...
# 20198  চাকমা মারমা একই না  চীন তাদের লাথি মেরেছে  আর ...   racism
# 20199                          চাকমা মানি চাইনিজ মাফিয়া   racism
# 20200  কাক কালো আফ্রিকান কালো  তুমিও কালো  পাউডার দিয...   racism
# 20201     খানকি সুন্দর হতে পারে কিন্তু   তুই নিগা থাকবি    racism
# 20202                                শালা গরিব এর বাচ্চা   racism
#
# [20203 rows x 3 columns]

# %%
import nltk
nltk.download('punkt')

multitoxicdata['new'] = multitoxicdata.apply(lambda row: nltk.word_tokenize(row['new']), axis=1)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
sw = pd.read_csv("/content/drive/MyDrive/datasett/stopwords-bn [MConverter.eu].csv")
sw.columns = ['Words']
sw.head()
sw = sw['Words']
sw.shape
# Out:
# (397,)

# %%
stop_words = ['এ', 'হয়', 'কি', 'কী', 'এর', 'কে', 'যে', 'এই', 'বা', 'সব', 'টি', 'তা',
       'সে', 'তাই', 'সেই', 'তার', 'আগে', 'যদি', 'আছে', 'আমি', 'এবং', 'করে', 'কার', 'এটি', 'হতে', 'যায়',
       'আরও', 'যাক', 'খুব', 'উপর', 'পরে', 'হবে', 'কেন', 'কখন', 'সকল', 'হয়', 'ঠিক', 'একই', 'কোন',
       'ছিল', 'খুবই', 'কোনো', 'অধীন', 'যারা', 'তারা', 'গুলি', 'তাকে', 'সেটা', 'সময়', 'আমার', 'আমরা', 'সবার',
       'উভয়', 'একটা', 'আপনি', 'নিয়ে', 'একটি', 'বন্ধ', 'জন্য', 'শুধু', 'যেটা', 'উচিত', 'মাঝে', 'থেকে', 'করবে',
       'আবার', 'উপরে', 'সেটি', 'কিছু', 'কারণ', 'যেমন', 'তিনি', 'মধ্যে', 'আমাকে', 'করছেন', 'তুলনা', 'তারপর',
       'নিজেই', 'থাকার', 'নিজের', 'পারেন', 'একবার', 'সঙ্গে', 'ইচ্ছা', 'নীচের', 'এগুলো', 'আপনার', 'অধীনে', 'কিংবা',
       'এখানে', 'তাহলে', 'কয়েক', 'জন্যে', 'হচ্ছে', 'তাদের', 'কোথায়', 'কিন্তু', 'নিজেকে', 'যতক্ষণ', 'আমাদের',
       'দ্বারা', 'আসো','হয়েছে', ' সঙ্গে', 'সেখানে', 'কিভাবে', 'মাধ্যমে', 'নিজেদের', 'তুলনায়', 'প্রতিটি',
       'তাদেরকে', 'ইত্যাদি', 'সম্পর্কে', 'সর্বাধিক', 'বিরুদ্ধে', 'অন্যান্য','দেখাচ্ছে','এইসব','একই','চায়','দিয়ে','অথচ','নিয়ে','বাকি','কিন্তু','এদের','অনেক','পারেনা','দেখান' ,'এক' ,'হয়ে','করছে ','ছাড়া','তুই','তোর','তুমিও','দেয়া ','থেকে','ওয়া','নিজার','ছিঃ','কিছু','থাকে','তুর','তো','তরফ','দিয়েছে','রেখে', 'গেছে ','তে',
      'আপনারা','হয়ে','যাবো','আইতেছি','এর','চাই','কিরে','সবাই','দিছে','দিবো','দিব','দিলি','রে','তোমাদের','যাব','আজকের','থাক','একসাথে','যাও','করেছি','তুরে','করলো','কারো','আসলো','এভাবে','তোমরা','এসেছে','দিচ্ছে','এইটা','দিলে','দিলো','করো','আসবে','একদিন','হতো','দেই','দাও','উনার','দেখলাম','লাগছে','আপনাদের','দেখলে','আসে','দেয়','দিলাম','কই','তোদের','কর','ছিলো','দে','তোকে','করুন','দিবে','পড়ে','যেয়ে','এরকম','এতো','তরে','ওরে','লাগে','তর','টা','দিয়া','তোমার','অর','একটু','আপনাদেরকে','তোমাকে','একজন','দেয়া','আপনারটা','আপনাকে','মত','আপনিও','আপনিই','আনা','হয়েছে','আজকে','তোরে','আজও','আছোস','আছি','আচ্ছা','আজকে','আছিলি','আছিস','আছেন','আগেও','আমরাও','আমিও','আরে','আরেক','আরেকজনকে','করছি','আসেন','ইউ','ইকটু','ইয়ে','ইয়েস']
for i in range(sw.shape[0]):
    stop_words.append(sw[i])
print(type(stop_words))
print(len(stop_words))
print(stop_words)

multitoxicdata['new']=multitoxicdata['new'].apply(lambda x: [item for item in x if item not in stop_words])
# Out:
# <class 'list'>
# 646
# ['এ', 'হয়', 'কি', 'কী', 'এর', 'কে', 'যে', 'এই', 'বা', 'সব', 'টি', 'তা', 'সে', 'তাই', 'সেই', 'তার', 'আগে', 'যদি', 'আছে', 'আমি', 'এবং', 'করে', 'কার', 'এটি', 'হতে', 'যায়', 'আরও', 'যাক', 'খুব', 'উপর', 'পরে', 'হবে', 'কেন', 'কখন', 'সকল', 'হয়', 'ঠিক', 'একই', 'কোন', 'ছিল', 'খুবই', 'কোনো', 'অধীন', 'যারা', 'তারা', 'গুলি', 'তাকে', 'সেটা', 'সময়', 'আমার', 'আমরা', 'সবার', 'উভয়', 'একটা', 'আপনি', 'নিয়ে', 'একটি', 'বন্ধ', 'জন্য', 'শুধু', 'যেটা', 'উচিত', 'মাঝে', 'থেকে', 'করবে', 'আবার', 'উপরে', 'সেটি', 'কিছু', 'কারণ', 'যেমন', 'তিনি', 'মধ্যে', 'আমাকে', 'করছেন', 'তুলনা', 'তারপর', 'নিজেই', 'থাকার', 'নিজের', 'পারেন', 'একবার', 'সঙ্গে', 'ইচ্ছা', 'নীচের', 'এগুলো', 'আপনার', 'অধীনে', 'কিংবা', 'এখানে', 'তাহলে', 'কয়েক', 'জন্যে', 'হচ্ছে', 'তাদের', 'কোথায়', 'কিন্তু', 'নিজেকে', 'যতক্ষণ', 'আমাদের', 'দ্বারা', 'আসো', 'হয়েছে', ' সঙ্গে', 'সেখানে', 'কিভাবে', 'মাধ্যমে', 'নিজেদের', 'তুলনায়', 'প্রতিটি', 'তাদেরকে', 'ইত্যাদি', 'সম্পর্কে', 'সর্বাধিক', 'বিরুদ্ধে', 'অন্যান্য', 'দেখাচ্ছে', 'এইসব', 'একই', 'চায়', 'দিয়ে', 'অথচ', 'নিয়ে', 'বাকি', 'কিন্তু', 'এদের', 'অনেক', 'পারেনা', 'দেখান', 'এক', 'হয়ে', 'করছে ', 'ছাড়া', 'তুই', 'তোর', 'তুমিও', 'দেয়া ', 'থেকে', 'ওয়া', 'নিজার', 'ছিঃ', 'কিছু', 'থাকে', 'তুর', 'তো', 'তরফ', 'দিয়েছে', 'রেখে', 'গেছে ', 'তে', 'আপনারা', 'হয়ে', 'যাবো', 'আইতেছি', 'এর', 'চাই', 'কিরে', 'সবাই', 'দিছে', 'দিবো', 'দিব', 'দিলি', 'রে', 'তোমাদের', 'যাব', 'আজকের', 'থাক', 'একসাথে', 'যাও', 'করেছি', 'তুরে', 'করলো', 'কারো', 'আসলো', 'এভাবে', 'তোমরা', 'এসেছে', 'দিচ্ছে', 'এইটা', 'দিলে', 'দিলো', 'করো', 'আসবে', 'একদিন', 'হতো', 'দেই', 'দাও', 'উনার', 'দেখলাম', 'লাগছে', 'আপনাদের', 'দেখলে', 'আসে', 'দেয়', 'দিলাম', 'কই', 'তোদের', 'কর', 'ছিলো', 'দে', 'তোকে', 'করুন', 'দিবে', 'পড়ে', 'যেয়ে', 'এরকম', 'এতো', 'তরে', 'ওরে', 'লাগে', 'তর', 'টা', 'দিয়া', 'তোমার', 'অর', 'একটু', 'আপনাদেরকে', 'তোমাকে', 'একজন', 'দেয়া', 'আপনারটা', 'আপনাকে', 'মত', 'আপনিও', 'আপনিই', 'আনা', 'হয়েছে', 'আজকে', 'তোরে', 'আজও', 'আছোস', 'আছি', 'আচ্ছা', 'আজকে', 'আছিলি', 'আছিস', 'আছেন', 'আগেও', 'আমরাও', 'আমিও', 'আরে', 'আরেক', 'আরেকজনকে', 'করছি', 'আসেন', 'ইউ', 'ইকটু', 'ইয়ে', 'ইয়েস', 'অথচ', 'অথবা', 'অনুযায়ী', 'অনেক', 'অনেকে', 'অনেকেই', 'অন্তত', 'অন্য', 'অবধি', 'অবশ্য', 'অর্থাত', 'আই', 'আগামী', 'আগে', 'আগেই', 'আছে', 'আজ', 'আদ্যভাগে', 'আপনার', 'আপনি', 'আবার', 'আমরা', 'আমাকে', 'আমাদের', 'আমার', 'আমি', 'আর', 'আরও', 'ই', 'ইত্যাদি', 'ইহা', 'উচিত', 'উত্তর', 'উনি', 'উপর', 'উপরে', 'এ', 'এঁদের', 'এঁরা', 'এই', 'একই', 'একটি', 'একবার', 'একে', 'এক্', 'এখন', 'এখনও', 'এখানে', 'এখানেই', 'এটা', 'এটাই', 'এটি', 'এত', 'এতটাই', 'এতে', 'এদের', 'এব', 'এবং', 'এবার', 'এমন', 'এমনকী', 'এমনি', 'এর', 'এরা', 'এল', 'এস', 'এসে', 'ঐ', 'ও', 'ওঁদের', 'ওঁর', 'ওঁরা', 'ওই', 'ওকে', 'ওখানে', 'ওদের', 'ওর', 'ওরা', 'কখনও', 'কত', 'কবে', 'কমনে', 'কয়েক', 'কয়েকটি', 'করছে', 'করছেন', 'করতে', 'করবে', 'করবেন', 'করলে', 'করলেন', 'করা', 'করাই', 'করায়', 'করার', 'করি', 'করিতে', 'করিয়া', 'করিয়ে', 'করে', 'করেই', 'করেছিলেন', 'করেছে', 'করেছেন', 'করেন', 'কাউকে', 'কাছ', 'কাছে', 'কাজ', 'কাজে', 'কারও', 'কারণ', 'কি', 'কিংবা', 'কিছু', 'কিছুই', 'কিন্তু', 'কী', 'কে', 'কেউ', 'কেউই', 'কেখা', 'কেন', 'কোটি', 'কোন', 'কোনও', 'কোনো', 'ক্ষেত্রে', 'কয়েক', 'খুব', 'গিয়ে', 'গিয়েছে', 'গিয়ে', 'গুলি', 'গেছে', 'গেল', 'গেলে', 'গোটা', 'চলে', 'চান', 'চায়', 'চার', 'চালু', 'চেয়ে', 'চেষ্টা', 'ছাড়া', 'ছাড়াও', 'ছিল', 'ছিলেন', 'জন', 'জনকে', 'জনের', 'জন্য', 'জন্যওজে', 'জানতে', 'জানা', 'জানানো', 'জানায়', 'জানিয়ে', 'জানিয়েছে', 'জে', 'জ্নজন', 'টি', 'ঠিক', 'তখন', 'তত', 'তথা', 'তবু', 'তবে', 'তা', 'তাঁকে', 'তাঁদের', 'তাঁর', 'তাঁরা', 'তাঁাহারা', 'তাই', 'তাও', 'তাকে', 'তাতে', 'তাদের', 'তার', 'তারপর', 'তারা', 'তারৈ', 'তাহলে', 'তাহা', 'তাহাতে', 'তাহার', 'তিনঐ', 'তিনি', 'তিনিও', 'তুমি', 'তুলে', 'তেমন', 'তো', 'তোমার', 'থাকবে', 'থাকবেন', 'থাকা', 'থাকায়', 'থাকে', 'থাকেন', 'থেকে', 'থেকেই', 'থেকেও', 'দিকে', 'দিতে', 'দিন', 'দিয়ে', 'দিয়েছে', 'দিয়েছেন', 'দিলেন', 'দু', 'দুই', 'দুটি', 'দুটো', 'দেওয়া', 'দেওয়ার', 'দেওয়া', 'দেখতে', 'দেখা', 'দেখে', 'দেন', 'দেয়', 'দ্বারা', 'ধরা', 'ধরে', 'ধামার', 'নতুন', 'নয়', 'না', 'নাই', 'নাকি', 'নাগাদ', 'নানা', 'নিজে', 'নিজেই', 'নিজেদের', 'নিজের', 'নিতে', 'নিয়ে', 'নিয়ে', 'নেই', 'নেও ...

# %%
multitoxicdata
# Out:
#                                                      new  \
# 0      [গুলার, জায়গামতো, চুঁচড়া, লাগিয়ে, দরকার, যত্তস...
# 1      [আসিফ, খানকির, পোলা, মারে, কুত্তা, চুদে, পয়দা,...
# 2      [শুয়োরের, জ্ঞান, সীমিত, সারাদিন, গাঁজাখোরদের, ...
# 3              [মাদ্রাসার, হোগুরকে, ডিলডো, মেরে, শাস্তি]
# 4                       [নাস্তিকতা, মানে, মানুষিক, রোগী]
# ...                                                  ...
# 20198  [চাকমা, মারমা, চীন, লাথি, মেরেছে, বাংলাদেশ, মরতে]
# 20199                     [চাকমা, মানি, চাইনিজ, মাফিয়া]
# 20200  [কাক, কালো, আফ্রিকান, কালো, কালো, পাউডার, হোবে...
# 20201                       [খানকি, সুন্দর, নিগা, থাকবি]
# 20202                               [শালা, গরিব, বাচ্চা]
#
#                                             comment_text  Labelss
# 0      এই গুলার জায়গামতো চুঁচড়া লাগিয়ে দেয়া দরকার যত্...   insult
# 1      আসিফ খানকির পোলা তোর মারে কুত্তা দিয়ে চুদে তোর...  obscene
# 2      শুয়োরের জ্ঞান সীমিত তাই সারাদিন গাঁজাখোরদের মত...   insult
# 3        এই মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি দেয়া হোক   insult
# 4                         নাস্তিকতা মানে ই মানুষিক রোগী    racism
# ...                                                  ...      ...
# 20198  চাকমা মারমা একই না  চীন তাদের লাথি মেরেছে  আর ...   racism
# 20199                          চাকমা মানি চাইনিজ মাফিয়া   racism
# 20200  কাক কালো আফ্রিকান কালো  তুমিও কালো  পাউডার দিয...   racism
# 20201     খানকি সুন্দর হতে পারে কিন্তু   তুই নিগা থাকবি    racism
# 20202                                শালা গরিব এর বাচ্চা   racism
#
# [20203 rows x 3 columns]

# %%
multitoxicdata["joint"]= multitoxicdata["new"].str.join(" ")

# %%
multitoxicdata['joint']
# Out:
# 0           গুলার জায়গামতো চুঁচড়া লাগিয়ে দরকার যত্তসব ভন্ড
# 1             আসিফ খানকির পোলা মারে কুত্তা চুদে পয়দা করসিল
# 2        শুয়োরের জ্ঞান সীমিত সারাদিন গাঁজাখোরদের চিল্লা...
# 3                      মাদ্রাসার হোগুরকে ডিলডো মেরে শাস্তি
# 4                              নাস্তিকতা মানে মানুষিক রোগী
#                                ...
# 20198            চাকমা মারমা চীন লাথি মেরেছে বাংলাদেশ মরতে
# 20199                            চাকমা মানি চাইনিজ মাফিয়া
# 20200           কাক কালো আফ্রিকান কালো কালো পাউডার হোবে গো
# 20201                              খানকি সুন্দর নিগা থাকবি
# 20202                                     শালা গরিব বাচ্চা
# Name: joint, Length: 20203, dtype: object

# %%
multitoxicdata['Labelss'].value_counts()
# Out:
# not toxic    9769
# obscene      3933
# threat       2841
# insult       2075
# racism       1585
# Name: Labelss, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Labelss',data=multitoxicdata)

# %%
#import label encoder 
from sklearn import preprocessing
#creating object
LE= preprocessing.LabelEncoder()
#Encode 
multitoxicdata['new_label'] = LE.fit_transform(multitoxicdata['Labelss'])

# %%
multitoxicdata.new_label
# Out:
# 0        0
# 1        2
# 2        0
# 3        0
# 4        3
#         ..
# 20198    3
# 20199    3
# 20200    3
# 20201    3
# 20202    3
# Name: new_label, Length: 20203, dtype: int64

# %%
import numpy as np
import pandas as pd
from plotly.offline import iplot
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
import re
from nltk.corpus import stopwords
from nltk import word_tokenize

# %%
all_words=multitoxicdata['new']

# %%
import gensim
from gensim.models import Word2Vec

# %%
wordVec = Word2Vec.load("/content/drive/MyDrive/datasett/100D-newepochmodel.txt").wv

# %%
wordVec.most_similar("খানকির")
# Out:
# [('ছেঁচকুনির', 0.6123166084289551),
#  ('উপস্তাপক', 0.6104114055633545),
#  ('খাংকির', 0.6101401448249817),
#  ('খাইঞ্চোদের', 0.5888468623161316),
#  ('ষ্কি', 0.5836299657821655),
#  ('চুতনার', 0.5803718566894531),
#  ('খানকিমাগির', 0.5749337673187256),
#  ('জুকার', 0.5737476348876953),
#  ('কিযে', 0.5706065893173218),
#  ('চুত্মারানীর', 0.56980299949646)]

# %%
# total numberof extracted words.
vocab=wordVec.vocab
print("The total number of words are : ",len(vocab))
# Out:
# The total number of words are :  35146

# %%
# print(vocab)
vocab=list(vocab.keys())

# %%
word_vec_dict={}
for word in vocab:
  word_vec_dict[word]=wordVec.get_vector(word)
print("The no of key-value pairs : ",len(word_vec_dict)) # should come equal to vocab size
# Out:
# The no of key-value pairs :  35146

# %%
# # just check
for word in vocab[:5]:
   print(word_vec_dict[word])

# %%
comment=multitoxicdata['joint'].values.tolist()

# %%
vocab_size = 40000
embedding_dim = 100
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# %%
tokenizer = Tokenizer(num_words=40000, oov_token=oov_tok)
tokenizer.fit_on_texts(comment)

word_index = tokenizer.word_index

sequences = tokenizer.texts_to_sequences(comment)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

print(word_index)

print(padded.shape)
# Out:
# {'<OOV>': 1, 'কথা': 2, 'ভাই': 3, 'সাথে': 4, 'ভালো': 5, 'মানুষ': 6, 'নাটক': 7, 'মাগি': 8, 'দরকার': 9, 'পোলা': 10, 'মাগির': 11, 'জুতা': 12, 'বাচ্চা': 13, 'বড়': 14, 'মারা': 15, 'বালের': 16, 'টাকা': 17, 'খারাপ': 18, 'খানকির': 19, 'মেয়ে': 20, 'সময়': 21, 'বাল': 22, 'বের': 23, 'মা': 24, 'দেশের': 25, 'নাম': 26, 'চুদি': 27, 'হাত': 28, 'শেষ': 29, 'পুটকি': 30, 'শালা': 31, 'ভাল': 32, 'দুধ': 33, 'দিমু': 34, 'আল্লাহ': 35, 'মেরে': 36, 'ছেলে': 37, 'দেশ': 38, 'দেখি': 39, 'খানকি': 40, 'মুখে': 41, 'দেশে': 42, 'বাংলাদেশের': 43, 'গালি': 44, 'ভিডিও': 45, 'সালা': 46, 'বললাম': 47, 'বাংলাদেশ': 48, 'বাবা': 49, 'সানাই': 50, 'মানুষের': 51, 'কইরা': 52, 'চোদা': 53, 'সুন্দর': 54, 'মাগী': 55, 'কুত্তা': 56, 'ছবি': 57, 'পুত': 58, 'জয়': 59, 'হাতে': 60, 'মারে': 61, 'মালাউন': 62, 'মন': 63, 'কুত্তার': 64, 'এসব': 65, 'লাল': 66, 'মাথা': 67, 'বিচার': 68, 'কেটে': 69, 'পাগল': 70, 'থাকলে': 71, 'মানে': 72, 'আবাল': 73, 'বছর': 74, 'মার': 75, 'কেমন': 76, 'হিরো': 77, 'চুদা': 78, 'কমেন্ট': 79, 'হালা': 80, 'লোক': 81, 'আসলে': 82, 'জানি': 83, 'স্যার': 84, 'বাসায়': 85, 'ইসলাম': 86, 'পো': 87, 'আরিপ্পা': 88, 'বিয়ে': 89, 'দের': 90, 'উচিৎ': 91, 'গেলো': 92, 'পারবে': 93, 'নষ্ট': 94, 'মুখ': 95, 'মাথায়': 96, 'ধন্যবাদ': 97, 'হোগা': 98, 'কম': 99, 'চুদে': 100, 'বাংলা': 101, 'সাকিব': 102, 'বেশী': 103, 'মুসলিম': 104, 'মজা': 105, 'বলছে': 106, 'ভুল': 107, 'হিজরা': 108, 'গাড়ি': 109, 'চোখ': 110, 'আলম': 111, 'আরো': 112, 'খবর': 113, 'ফালতু': 114, 'বাংলাদেশে': 115, 'নিয়া': 116, 'কেমনে': 117, 'গুলো': 118, 'ছোট': 119, 'গরম': 120, 'মাইরা': 121, 'গু': 122, 'ভিতরে': 123, 'বিচি': 124, 'সরকার': 125, 'গান': 126, 'বাজে': 127, 'ফেলা': 128, 'হালার': 129, 'খান': 130, 'পাইলে': 131, 'মারতে': 132, 'খুশি': 133, 'রাস্তায়': 134, 'গুলা': 135, 'জাতি': 136, 'হিসেবে': 137, 'থাকতে': 138, 'লজ্জা': 139, 'ছি': 140, 'হা': 141, 'পতিতা': 142, 'বাপ': 143, 'ফোন': 144, 'খেয়ে': 145, 'কারন': 146, 'নিচে': 147, 'পুটকির': 148, 'বলছি': 149, 'বিশ্বাস': 150, 'বলার': 151, 'জানে': 152, 'অবস্থা': 153, 'রা': 154, 'তোরা': 155, 'সমস্যা': 156, 'করবো': 157, 'জন্ম': 158, 'আশা': 159, 'খেতে': 160, 'কোথায়': 161, 'যাই': 162, 'তাকিয়ে': 163, 'মাদারচোদ': 164, 'আরিফ': 165, 'কেনো': 166, 'মেয়ের': 167, 'লাগবে': 168, 'দেখার': 169, 'বুঝতে': 170, 'হওয়ার': 171, 'ভারতের': 172, 'ডিম': 173, 'হিন্দু': 174, 'দিতাম': 175, 'শুনে': 176, 'সেদিন': 177, 'অপু': 178, 'পাওয়া': 179, 'লেখা': 180, 'নাস্তিক': 181, 'পানি': 182, 'উঠে': 183, 'খালি': 184, 'পারলে': 185, 'সারা': 186, 'মদ': 187, 'হয়তো': 188, 'নামে': 189, 'দেইখা': 190, 'চেয়ে': 191, 'কখনো': 192, 'ছেলেকে': 193, 'সন্তান': 194, 'রাস্তার': 195, 'মিথ্যা': 196, 'আল্লাহর': 197, 'পুলিশ': 198, 'লাইক': 199, 'বউ': 200, 'বেশ্যা': 201, 'আসলেই': 202, 'কতো': 203, 'দাঁড়িয়ে': 204, 'কষ্ট': 205, 'শাকিব': 206, 'পা': 207, 'শান্তি': 208, 'চদা': 209, 'চুদির': 210, 'ধর্ম': 211, 'যাওয়ার': 212, 'কারণে': 213, 'লাভ': 214, 'বাবার': 215, 'ভিতর': 216, 'মায়ের': 217, 'হিজড়া': 218, 'পিক': 219, 'গরু': 220, 'চোখে': 221, 'বাদ': 222, 'খাওয়া': 223, 'মহিলা': 224, 'পাপন': 225, 'কালা': 226, 'হওয়া': 227, 'বড়': 228, 'নি': 229, 'মেয়েদের': 230, 'গায়ে': 231, 'হোগার': 232, 'বলি': 233, 'পায়': 234, 'করলাম': 235, 'পাশে': 236, 'মালাউনের': 237, 'শাস্তি': 238, 'সাদা': 239, 'খেলা': 240, 'মাল': 241, 'দোষ': 242, 'চেহারা': 243, 'আসছে': 244, 'সবাইকে': 245, 'পুরো': 246, 'ছেলের': 247, 'সত্যি': 248, 'দুইটা': 249, 'গরুর': 250, 'হইছে': 251, 'লাথি': 252, 'দেয়ার': 253, 'মার্কা': 254, 'মাগীর': 255, 'টাকার': 256, 'কোটা': 257, 'নামের': 258, 'মারি': 259, 'মাকে': 260, 'ভয়': 261, 'ইচ্ছে': 262, 'গেলাম': 263, 'গালে': 264, 'ভারত': 265, 'খা': 266, 'দালাল': 267, 'পারতাম': 268, 'পুরা': 269, 'পাছায়': 270, 'করতাম': 271, 'জায়গায়': 272, 'দল': 273, 'এগিয়ে': 274, 'করব': 275, 'কিনা': 276, 'দুধের': 277, 'আগের': 278, 'জীবন': 279, 'জিজ্ঞেস': 280, 'শিওর': 281, 'বাট': 282, 'কুকুর': 283, 'ঘরে': 284, 'প্রশ্ন': 285, 'খুঁজে': 286, 'পিটা': 287, 'বন্ধু': 288, 'আসা': 289, 'সাহেব': 290, 'দিবেন': 291, 'ভাইয়া': 292, 'মানুষকে': 293, 'অবশ্যই': 294, 'মেয়েকে': 295, 'ভইরা': 296, 'নিউজ': 297, 'খাইয়া': 298, 'কঠিন': 299, 'শিক্ষা': 300, 'পরিচালক': 301, 'ব্যাপার': 302, 'বল': 303, 'ভরে': 304, 'তাইলে': 305, 'জুতার': 306, 'বাংলার': ...
# (20203, 120)

# %%
from imblearn.over_sampling import SMOTE,ADASYN,RandomOverSampler
from collections import Counter
from matplotlib import pyplot
oversamplee = RandomOverSampler(random_state=0)
Xxx, yyy = oversamplee.fit_resample(padded,multitoxicdata['new_label'])
counter = Counter(yyy)
print(counter)
# Out:
# Counter({0: 9769, 2: 9769, 3: 9769, 4: 9769, 1: 9769})

# %%
from sklearn.model_selection import train_test_split
X =Xxx
Y = to_categorical(yyy)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0, test_size=0.15,stratify=Y)

testing_labels = Y_test
training_labels = Y_train

# %%
import numpy as np
training_padded = np.array(X_train)
testing_padded = np.array(X_test)
testing_labels = np.array(testing_labels)
training_labels = np.array(training_labels)

# %%
#CREATING THE EMBEDDING MATRIX

# %%
hits = 0
misses = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((vocab_size, 100))
for word, i in word_index.items():
    embedding_vector = word_vec_dict.get(word)
    if embedding_vector is not None:
        # Words not found in embedding index will be all-zeros.
        # This includes the representation for "padding" and "OOV"
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1
print("Converted %d words (%d misses)" % (hits, misses))
# Out:
# Converted 35144 words (3 misses)

# %%
import tensorflow as tf

# %%
#15epooc:sectionLSTM

# %%
model15 = tf.keras.Sequential([
tf.keras.layers.Embedding(40000,100,input_length=max_length,weights=[embedding_matrix],trainable=False),
    #tf.keras.layers.Conv1D(filters=200, kernel_size=3, padding='same', activation='relu'),
    tf.keras.layers.LSTM(200, dropout=0.2,return_sequences=True,  recurrent_dropout=0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])
adam=tf.keras.optimizers.Adam(learning_rate=0.001)
model15.compile(loss='categorical_crossentropy',optimizer=adam,metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model15.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 120, 100)          4000000
#
#  lstm_2 (LSTM)               (None, 120, 200)          240800
#
#  flatten_1 (Flatten)         (None, 24000)             0
#
#  dense_4 (Dense)             (None, 32)                768032
#
#  dense_5 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 5,008,997
# Trainable params: 1,008,997
# Non-trainable params: 4,000,000
# _________________________________________________________________

# %%
print(training_padded.shape)
print(training_labels.shape)
print(testing_padded.shape)
print(testing_labels.shape)
num_epochs = 50
history15 = model15.fit(training_padded, training_labels, epochs=num_epochs ,validation_data=(testing_padded, testing_labels),
                   callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15), 
        tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_frequency=1)
    ])
# Out:
# (41518, 120)
# (41518, 5)
# (7327, 120)
# (7327, 5)
# Epoch 1/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.8279 - accuracy: 0.6794
# Epoch 1: val_loss improved from inf to 0.64629, saving model to /content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5
# 1298/1298 [==============================] - 581s 446ms/step - loss: 0.8279 - accuracy: 0.6794 - val_loss: 0.6463 - val_accuracy: 0.7580
# Epoch 2/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.5586 - accuracy: 0.7881
# Epoch 2: val_loss improved from 0.64629 to 0.48807, saving model to /content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5
# 1298/1298 [==============================] - 571s 440ms/step - loss: 0.5586 - accuracy: 0.7881 - val_loss: 0.4881 - val_accuracy: 0.8211
# Epoch 3/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.8454
# Epoch 3: val_loss improved from 0.48807 to 0.39486, saving model to /content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5
# 1298/1298 [==============================] - 565s 436ms/step - loss: 0.4202 - accuracy: 0.8454 - val_loss: 0.3949 - val_accuracy: 0.8598
# Epoch 4/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.3370 - accuracy: 0.8764
# Epoch 4: val_loss improved from 0.39486 to 0.33290, saving model to /content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5
# 1298/1298 [==============================] - 567s 437ms/step - loss: 0.3370 - accuracy: 0.8764 - val_loss: 0.3329 - val_accuracy: 0.8892
# Epoch 5/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.2875 - accuracy: 0.8948
# Epoch 5: val_loss improved from 0.33290 to 0.31179, saving model to /content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5
# 1298/1298 [==============================] - 571s 440ms/step - loss: 0.2875 - accuracy: 0.8948 - val_loss: 0.3118 - val_accuracy: 0.8971
# Epoch 6/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.2546 - accuracy: 0.9053
# Epoch 6: val_loss improved from 0.31179 to 0.30924, saving model to /content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5
# 1298/1298 [==============================] - 561s 432ms/step - loss: 0.2546 - accuracy: 0.9053 - val_loss: 0.3092 - val_accuracy: 0.9042
# Epoch 7/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.9172
# Epoch 7: val_loss improved from 0.30924 to 0.28572, saving model to /content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5
# 1298/1298 [==============================] - 591s 455ms/step - loss: 0.2263 - accuracy: 0.9172 - val_loss: 0.2857 - val_accuracy: 0.9114
# Epoch 8/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.2083 - accuracy: 0.9230
# Epoch 8: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 575s 443ms/step - loss: 0.2083 - accuracy: 0.9230 - val_loss: 0.2880 - val_accuracy: 0.9193
# Epoch 9/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1959 - accuracy: 0.9271
# Epoch 9: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 577s 445ms/step - loss: 0.1959 - accuracy: 0.9271 - val_loss: 0.3075 - val_accuracy: 0.9094
# Epoch 10/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1866 - accuracy: 0.9310
# Epoch 10: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 569s 439ms/step - loss: 0.1866 - accuracy: 0.9310 - val_loss: 0.3254 - val_accuracy: 0.9159
# Epoch 11/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1735 - accuracy: 0.9364
# Epoch 11: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 564s 434ms/step - loss: 0.1735 - accuracy: 0.9364 - val_loss: 0.2947 - val_accuracy: 0.9192
# Epoch 12/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9369
# Epoch 12: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 572s 441ms/step - loss: 0.1674 - accuracy: 0.9369 - val_loss: 0.2861 - val_accuracy: 0.9207
# Epoch 13/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9387
# Epoch 13: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 567s 436ms/step - loss: 0.1608 - accuracy: 0.9387 - val_loss: 0.3096 - val_accuracy: 0.9166
# Epoch 14/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9409
# Epoch 14: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 561s 432ms/step - loss: 0.1569 - accuracy: 0.9409 - val_loss: 0.3028 - val_accuracy: 0.9180
# Epoch 15/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9421
# Epoch 15: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 562s 433ms/step - loss: 0.1521 - accuracy: 0.9421 - val_loss: 0.3092 - val_accuracy: 0.9240
# Epoch 16/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 0.9455
# Epoch 16: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 558s 430ms/step - loss: 0.1449 - accuracy: 0.9455 - val_loss: 0.3123 - val_accuracy: 0.9243
# Epoch 17/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9465
# Epoch 17: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 552s 425ms/step - loss: 0.1410 - accuracy: 0.9465 - val_loss: 0.2997 - val_accuracy: 0.9245
# Epoch 18/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.9482
# Epoch 18: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 558s 430ms/step - loss: 0.1369 - accuracy: 0.9482 - val_loss: 0.2954 - val_accuracy: 0.9267
# Epoch 19/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9478
# Epoch 19: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 568s 438ms/step - loss: 0.1378 - accuracy: 0.9478 - val_loss: 0.3081 - val_accuracy: 0.9252
# Epoch 20/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9485
# Epoch 20: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 562s 433ms/step - loss: 0.1337 - accuracy: 0.9485 - val_loss: 0.3014 - val_accuracy: 0.9304
# Epoch 21/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9507
# Epoch 21: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 558s 430ms/step - loss: 0.1287 - accuracy: 0.9507 - val_loss: 0.3006 - val_accuracy: 0.9286
# Epoch 22/50
# 1298/1298 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9507
# Epoch 22: val_loss did not improve from 0.28572
# 1298/1298 [==============================] - 563s 434ms/step - loss: 0.1281 - accuracy: 0.9507 - val_loss: 0.3041 - val_accuracy: 0.9301

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history15, "accuracy")
plot_graphs(history15, "loss")

# %%
from keras.models import load_model
model1 = load_model('/content/drive/MyDrive/datasett/Saved_Models/word2vecDeepLearning/LSTMmodelvec15_best(em).hdf5')
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
loss,acc=model1.evaluate(testing_padded,testing_labels)
print('Test accuracy:%f'%(acc*100))
# Out:
# 229/229 [==============================] - 11s 34ms/step - loss: 0.2857 - accuracy: 0.9114
# Test accuracy:91.142350

# %%
sentence = ['  খুন করব ']    
sequences = tokenizer.texts_to_sequences(sentence)
paddedd = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

pred=model1.predict(paddedd)
print(pred)
labels = ['insult','not toxic', 'obscene', 'racism', 'threat' ]
labels[np.argmax(pred)]
# Out:
# [[2.2462769e-08 1.8256936e-02 3.3637603e-05 1.5728225e-06 9.8170781e-01]]
# 'threat'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
rounded_predictions15 = np.argmax(model1.predict(testing_padded), axis=-1)
rounded_labels15=np.argmax(testing_labels, axis=1)
cm = confusion_matrix(y_true=rounded_labels15, y_pred=rounded_predictions15)


class_names = ['insult','not toxic','obscene','racism','threat']


fig = plt.figure(figsize=(16, 14))
ax= plt.subplot()
sns.set(font_scale=2) 
sns.heatmap(cm, annot=True, ax = ax, fmt = 'g'); 

ax.set_xlabel('Predicted', fontsize=25)
ax.xaxis.set_label_position('bottom')
plt.xticks(rotation=90)
ax.xaxis.set_ticklabels(class_names, fontsize = 20)
ax.xaxis.tick_bottom()

ax.set_ylabel('Actual', fontsize=25)
ax.yaxis.set_ticklabels(class_names, fontsize = 20)
plt.yticks(rotation=0)

plt.title('LSTM-Vec_Confusion Matrix', fontsize=20)

plt.savefig('/content/drive/MyDrive/datasett/images of models/word2vecDLconfusionmodels/RealxLSTM-word2vec_confusionmatrix.png')

# %%
from sklearn.metrics import classification_report
print(classification_report(rounded_labels15,rounded_predictions15))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      1466
#            1       0.91      0.87      0.89      1466
#            2       0.90      0.86      0.88      1465
#            3       0.97      0.96      0.96      1465
#            4       0.93      0.93      0.93      1465
#
#     accuracy                           0.91      7327
#    macro avg       0.91      0.91      0.91      7327
# weighted avg       0.91      0.91      0.91      7327

# %%
from sklearn.metrics import precision_score, recall_score ,f1_score
vLSTMF1=f1_score(rounded_labels15,rounded_predictions15,average='macro')
print(vLSTMF1)
VLSTMRecall=recall_score(rounded_labels15,rounded_predictions15,average='macro')
print(VLSTMRecall)
VLSTMPrecision=precision_score(rounded_labels15,rounded_predictions15,average='macro')
print(VLSTMPrecision)
# Out:
# 0.9113353175177196
# 0.9114256713026554
# 0.9124329727350476

# %%
from sklearn.metrics import precision_recall_fscore_support
def specificity(test,predict):
  res = []
  for l in [0,1,2,3,4]:
    prec,recall,_,_ = precision_recall_fscore_support(np.array(test)==l,
                                                      np.array(predict)==l,
                                                      pos_label=True,average=None)
    res.append(recall[0])
  return res
def weightspecificiyforDL(weights):
 s0=weights[0]
 s1=weights[1]
 s2=weights[2]
 s3=weights[3]
 s4=weights[4]
 weight=(s0+s1+s2+s3+s4)/5
 return weight
specificityLSTMembedd=specificity(rounded_labels15,rounded_predictions15)
weightspecLSTMembedd=weightspecificiyforDL(specificityLSTMembedd)
print(weightspecLSTMembedd)
# Out:
# 0.977855354958972
